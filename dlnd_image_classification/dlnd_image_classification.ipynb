# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 7
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 7:
# Image - Min Value: 9 Max Value: 248
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    print(x)
    
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test
#   [[ 22   8 224]
#    [159 246 184]
#    [ 91  78 219]
#    ...,
#    [242  60   0]
#    [240 223 116]
#    [ 91 137 187]]
#
#   ...,
#   [[147 109 204]
#    [  8 253 132]
#    [ 63 205  90]
#    ...,
#    [162 151 131]
#    [249 214 120]
#    [228  20  54]]
#
#   [[228 170  63]
#    [ 46 129 117]
#    [ 93  66 198]
#    ...,
#    [127  48 243]
#    [ 21 226 114]
#    [ 74 116 197]]
#
#   [[102 248 253]
#    [159  64 204]
#    [225 229 194]
#    ...,
#    [ 53 185  67]
#    [194  37 213]
#    [249 172 132]]]
#
#
#  [[[212  18 150]
#    [ 98  77 150]
#    [  9  86 206]
#    ...,
#    [ 47 160 155]
#    [173 232  49]
#    [231 154 236]]
#
#   [[128  25 106]
#    [216  67  64]
#    [239 197 151]
#    ...,
#    [118 142 138]
#    [ 74  42  89]
#    [ 45 109  39]]
#
#   [[ 73 150 196]
#    [101  66  37]
#    [238  31  16]
#    ...,
#    [ 13  57  75]
#    [223  43  35]
#    [188  36 166]]
#
#   ...,
#   [[ 27 158 135]
#    [164 116 118]
#    [234 208  78]
#    ...,
#    [ 30  17 109]
#    [ 52 192 127]
#    [247  44  46]]
#
#   [[138  75 164]
#    [112 206 136]
#    [180  89 224]
#    ...,
#    [ 82 174  60]
#    [230 117 205]
#    [ 16 130  89]]
#
#   [[133 208 237]
#    [ 91  23 155]
#    [ 89  74 120]
#    ...,
#    [120 215  93]
#    [ 39  28  70]
#    [ 11   3  74]]]
#
#
#  [[[156 156 156]
#    [  3 132 117]
#    [ 90 126 246]
#    ...,
#    [ 62 174 194]
#    [187 253 133]
#    [214 246 183]]
#
#   [[220  32 219]
#    [160  18  43]
#    [216 223 224]
#    ...,
#    [131 196 231]
#    [ 42  90 110]
#    [248  62 201]]
#
#   [[190 168  26]
#    [ 17 104  83]
#    [235 187  62]
#    ...,
#    [212 203 124]
#    [156  82 191]
#    [163  73  38]]
#
#   ...,
#   [[ 58 211  52]
#    [ 48   0 105]
#    [229 198  96]
#    ...,
#    [ 14 141  88]
#    [ 10 109  75]
#    [190 217  56]]
#
#   [[170  48  74]
#    [ 14 219 160]
#    [211 229 227]
#    ...,
#    [225  31 159]
#    [ 29 206 202]
#    [214  32 207]]
#
#   [[250 209  59]
#    [200 114  58]
#    [ 86 249 170]
#    ...,
#    [143  41 121]
#    [ 81 200 121]
#    [194 152  56]]]]
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer

encoder = LabelBinarizer()
encoder.fit(range(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return encoder.transform(x)



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)
# Out:
# [[[[ 59  62  63]
#    [ 43  46  45]
#    [ 50  48  43]
#    ...,
#    [158 132 108]
#    [152 125 102]
#    [148 124 103]]
#
#   [[ 16  20  20]
#    [  0   0   0]
#    [ 18   8   0]
#    ...,
#    [123  88  55]
#    [119  83  50]
#    [122  87  57]]
#
#   [[ 25  24  21]
#    [ 16   7   0]
#    [ 49  27   8]
#    ...,
#    [118  84  50]
#    [120  84  50]
#    [109  73  42]]
#
#   ...,
#   [[208 170  96]
#    [201 153  34]
#    [198 161  26]
#    ...,
#    [160 133  70]
#    [ 56  31   7]
#    [ 53  34  20]]
#
#   [[180 139  96]
#    [173 123  42]
#    [186 144  30]
#    ...,
#    [184 148  94]
#    [ 97  62  34]
#    [ 83  53  34]]
#
#   [[177 144 116]
#    [168 129  94]
#    [179 142  87]
#    ...,
#    [216 184 140]
#    [151 118  84]
#    [123  92  72]]]
#
#
#  [[[154 177 187]
#    [126 137 136]
#    [105 104  95]
#    ...,
#    [ 91  95  71]
#    [ 87  90  71]
#    [ 79  81  70]]
#
#   [[140 160 169]
#    [145 153 154]
#    [125 125 118]
#    ...,
#    [ 96  99  78]
#    [ 77  80  62]
#    [ 71  73  61]]
#
#   [[140 155 164]
#    [139 146 149]
#    [115 115 112]
#    ...,
#    [ 79  82  64]
#    [ 68  70  55]
#    [ 67  69  55]]
#
#   ...,
#   [[175 167 166]
#    [156 154 160]
#    [154 160 170]
#    ...,
#    [ 42  34  36]
#    [ 61  53  57]
#    [ 93  83  91]]
#
#   [[165 154 128]
#    [156 152 130]
#    [159 161 142]
#    ...,
#    [103  93  96]
#    [123 114 120]
#    [131 121 131]]
#
#   [[163 148 120]
#    [158 148 122]
#    [163 156 133]
#    ...,
#    [143 133 139]
#    [143 134 142]
#    [143 133 144]]]
#
#
#  [[[255 255 255]
#    [253 253 253]
#    [253 253 253]
#    ...,
#    [253 253 253]
#    [253 253 253]
#    [253 253 253]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [254 254 254]
#    [254 254 254]
#    ...,
#    [254 254 254]
#    [254 254 254]
#    [254 254 254]]
#
#   ...,
#   [[113 120 112]
#    [111 118 111]
#    [105 112 106]
#    ...,
#    [ 72  81  80]
#    [ 72  80  79]
#    [ 72  80  79]]
#
#   [[111 118 110]
#    [104 111 104]
#    [ 99 106  98]
#    ...,
#    [ 68  75  73]
#    [ 70  76  75]
#    [ 78  84  82]]
#
#    [ 33  25  14]
#    ...,
#    [ 24  23  50]
#    [ 26  23  53]
#    [ 25  20  47]]]
#
#
#  [[[ 25  40  12]
#    [ 15  36   3]
#    [ 23  41  18]
#    ...,
#    [ 61  82  78]
#    [ 92 113 112]
#    [ 75  89  92]]
#
#   [[ 12  25   6]
#    [ 20  37   7]
#    [ 24  36  15]
#    ...,
#    [115 134 138]
#    [149 168 177]
#    [104 117 131]]
#
#   [[ 12  25  11]
#    [ 15  29   6]
#    [ 34  40  24]
#    ...,
#    [154 172 182]
#    [157 175 192]
#    [116 129 151]]
#
#   ...,
#   [[100 129  81]
#    [103 132  84]
#    [104 134  86]
#    ...,
#    [ 97 128  84]
#    [ 98 126  84]
#    [ 91 121  79]]
#
#   [[103 132  83]
#    [104 131  83]
#    [107 135  87]
#    ...,
#    [101 132  87]
#    [ 99 127  84]
#    [ 92 121  79]]
#
#   [[ 95 126  78]
#    [ 95 123  76]
#    [101 128  81]
#    ...,
#    [ 93 124  80]
#    [ 95 123  81]
#    [ 92 120  80]]]
#
#
#  [[[ 73  78  75]
#    [ 98 103 113]
#    [ 99 106 114]
#    ...,
#    [135 150 152]
#    [135 149 154]
#    [203 215 223]]
#
#   [[ 69  73  70]
#    [ 84  89  97]
#    [ 68  75  81]
#    ...,
#    [ 85  95  89]
#    [ 71  82  80]
#    [120 133 135]]
#
#   [[ 69  73  70]
#    [ 90  95 100]
#    [ 62  71  74]
#    ...,
#    [ 74  81  70]
#    [ 53  62  54]
#    [ 62  74  69]]
#
#   ...,
#   [[123 128  96]
#    [132 132 102]
#    [129 128 100]
#    ...,
#    [108 107  88]
#    [ 62  60  55]
#    [ 27  27  28]]
#
#   [[115 121  91]
#    [123 124  95]
#    [129 126  99]
#    ...,
#    [115 116  94]
#    [ 66  65  59]
#    [ 27  27  27]]
#
#   [[116 120  90]
#    [121 122  94]
#    [129 128 101]
#    ...,
#    [116 115  94]
#    [ 68  65  58]
#    [ 27  26  26]]]]

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    
    return tf.placeholder(tf.float32, shape=[None, n_classes], name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # Weight and bias
    channels = x_tensor.get_shape().as_list()[3]

    weights = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], channels, conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    # Apply convolution
    conv_layer = tf.nn.conv2d(x_tensor, weights, strides=[1, conv_strides[0], conv_strides[1], 1], padding="SAME")
    
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    
    # Apply non-linear activation function
    conv_layer = tf.nn.relu(conv_layer)
    
    # Apply max-pooling
    conv_layer = tf.nn.max_pool(conv_layer, \
                                ksize=[1, pool_ksize[0], pool_ksize[1], 1], \
                                strides=[1, pool_strides[0], pool_strides[1], 1], \
                                padding='SAME')
    
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dim_list = x_tensor.get_shape().as_list()
    batch_size = dim_list[0]
    height = dim_list[1]
    width = dim_list[2]
    depth = dim_list[3]
    
    flattened = int(height * width * depth)
    
    return tf.reshape(x_tensor, [-1, flattened])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_in = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.random_normal([num_in, num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fully_conn = tf.add(tf.matmul(x_tensor, weights), bias)
    
    fully_conn = tf.nn.relu(fully_conn)
    
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_in = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.random_normal([num_in, num_outputs]))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fully_conn = tf.add(tf.matmul(x_tensor, weights), bias)
    
    return fully_conn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Variable initialization
    conv_ksize = (3, 3)
    conv_strides = (2, 2)
    pool_ksize = (2, 2)
    pool_strides = (1, 1)
    conv_num_outputs = 48
    
    # CNN layer 1 -- 32x32x3 to 16x16x48
    conv_layer = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # CNN layer 2 -- 16x16x48 to 8x8x192
    conv_layer = conv2d_maxpool(conv_layer, 192, (2, 2), conv_strides, pool_ksize, (1, 1))
    
    # CNN layer 3 -- 8x8x192 to 4x4x384
    conv_layer = conv2d_maxpool(conv_layer, 384, (2, 2), conv_strides, (1, 1), pool_strides)
    
    # CNN layer 4 - 4x4x384 to 2x2x512
    conv_layer = conv2d_maxpool(conv_layer, 512, (2, 2), (2, 2), (1, 1), (1, 1))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    # 2x2x512 to 2048
    conv_layer = flatten(conv_layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    # Dropout -- 3072 to (keep_prob * 3072)
    fully_conn_layer = tf.nn.dropout(conv_layer, keep_prob)
    
    # Fully connected layer 1 -- (keep_prob * 3072) to 512
    fully_conn_layer = fully_conn(conv_layer, 512)
    
    # Fully connected layer 2 -- 512 to 128
    fully_conn_layer = fully_conn(fully_conn_layer, 128)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    # Output layer -- 128 to 10
    out = output(fully_conn_layer, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
        x: feature_batch, 
        y: label_batch, 
        keep_prob: keep_probability
    })
    
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch, 
        y: label_batch,
        keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.})
        
    print('Loss: {:>10.4f} | Validation Accuracy: {:.4f}'.format(
        loss,
        valid_acc))
    
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 500
batch_size = 128
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 13362677.0000 | Validation Accuracy: 0.2184
# Epoch  2, CIFAR-10 Batch 1:  Loss: 8406282.0000 | Validation Accuracy: 0.2516
CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4234
# Epoch 69, CIFAR-10 Batch 1:  Loss: 11745.3457 | Validation Accuracy: 0.4294
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4358
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4310
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4402
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4368
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4448
# Epoch 75, CIFAR-10 Batch 1:  Loss: 12035.1689 | Validation Accuracy: 0.4250
# Epoch 76, CIFAR-10 Batch 1:  Loss:  7284.5566 | Validation Accuracy: 0.4384
# Epoch 77, CIFAR-10 Batch 1:  Loss:  7479.7378 | Validation Accuracy: 0.4296
# Epoch 78, CIFAR-10 Batch 1:  Loss: 12671.8936 | Validation Accuracy: 0.4364
# Epoch 79, CIFAR-10 Batch 1:  Loss: 37135.1484 | Validation Accuracy: 0.4328
# Epoch 80, CIFAR-10 Batch 1:  Loss: 44947.9648 | Validation Accuracy: 0.4282
# Epoch 81, CIFAR-10 Batch 1:  Loss: 10005.7500 | Validation Accuracy: 0.4360
# Epoch 82, CIFAR-10 Batch 1:  Loss: 22359.6992 | Validation Accuracy: 0.4532
# Epoch 83, CIFAR-10 Batch 1:  Loss: 42937.1250 | Validation Accuracy: 0.4512
# Epoch 84, CIFAR-10 Batch 1:  Loss:  2885.2251 | Validation Accuracy: 0.4538
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4664
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4582
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4570
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4558
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4562
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4606
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4490
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4560
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4582
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4594
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4642
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4668
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4680
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4678
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4524
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4592
# Epoch 101, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4584
# Epoch 102, CIFAR-10 Batch 1:  Loss:  4720.0625 | Validation Accuracy: 0.4514
# Epoch 103, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4624
# Epoch 104, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4560
# Epoch 105, CIFAR-10 Batch 1:  Loss:  4971.9624 | Validation Accuracy: 0.4610
# Epoch 106, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4640
# Epoch 107, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4646
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4590
# Epoch 109, CIFAR-10 Batch 1:  Loss:  1768.7125 | Validation Accuracy: 0.4584
# Epoch 110, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4542
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4600
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4566
# Epoch 113, CIFAR-10 Batch 1:  Loss: 28533.1504 | Validation Accuracy: 0.4488
# Epoch 114, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4570
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4720
# Epoch 116, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4638
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4622
# Epoch 118, CIFAR-10 Batch 1:  Loss:  6939.5376 | Validation Accuracy: 0.4708
# Epoch 119, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4654
# Epoch 120, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4600
# Epoch 121, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4618
# Epoch 122, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4594
# Epoch 123, CIFAR-10 Batch 1:  Loss:   146.5188 | Validation Accuracy: 0.4678
# Epoch 124, CIFAR-10 Batch 1:  Loss: 11735.3184 | Validation Accuracy: 0.4528
# Epoch 125, CIFAR-10 Batch 1:  Loss:  4623.2500 | Validation Accuracy: 0.4686
# Epoch 126, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.
CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5284
# Epoch 474, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5248
# Epoch 475, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5208
# Epoch 476, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5344
# Epoch 477, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5340
# Epoch 478, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5282
# Epoch 479, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5244
# Epoch 480, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5292
# Epoch 481, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5270
# Epoch 482, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5228
# Epoch 483, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5250
# Epoch 484, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5220
# Epoch 485, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5260
# Epoch 486, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5230
# Epoch 487, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5276
# Epoch 488, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5304
# Epoch 489, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5334
# Epoch 490, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5264
# Epoch 491, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5214
# Epoch 492, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5300
# Epoch 493, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5278
# Epoch 494, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5250
# Epoch 495, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5284
# Epoch 496, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5228
# Epoch 497, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5320
# Epoch 498, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5338
# Epoch 499, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5246
# Epoch 500, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5258

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 9467156.0000 | Validation Accuracy: 0.2240
# Epoch  1, CIFAR-10 Batch 2:  Loss: 7670711.5000 | Validation Accuracy: 0.2590
# Epoch  1, CIFAR-10 Batch 3:  Loss: 6961027.0000 | Validation Accuracy: 0.2698
# Epoch  1, CIFAR-10 Batch 4:  Loss: 5782703.0000 | Validation Accuracy: 0.2960
# Epoch  1, CIFAR-10 Batch 5:  Loss: 4849550.0000 | Validation Accuracy: 0.2958
# Epoch  2, CIFAR-10 Batch 1:  Loss: 4059958.0000 | Validation Accuracy: 0.3094
# Epoch  2, CIFAR-10 Batch 2:  Loss: 4321885.0000 | Validation Accuracy: 0.2984
# Epoch  2, CIFAR-10 Batch 3:  Loss: 2724991.2500 | Validation Accuracy: 0.3166
# Epoch  2, CIFAR-10 Batch 4:  Loss: 3143076.5000 | Validation Accuracy: 0.3236
# Epoch  2, CIFAR-10 Batch 5:  Loss: 2683661.5000 | Validation Accuracy: 0.3240
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2304286.0000 | Validation Accuracy: 0.3464
# Epoch  3, CIFAR-10 Batch 2:  Loss: 2894008.5000 | Validation Accuracy: 0.3328
# Epoch  3, CIFAR-10 Batch 3:  Loss: 1710156.5000 | Validation Accuracy: 0.3376
# Epoch  3, CIFAR-10 Batch 4:  Loss: 1699459.3750 | Validation Accuracy: 0.3454
# Epoch  3, CIFAR-10 Batch 5:  Loss: 1731228.3750 | Validation Accuracy: 0.3506
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1501682.3750 | Validation Accuracy: 0.3500
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1840938.5000 | Validation Accuracy: 0.3450
# Epoch 16, CIFAR-10 Batch 5:  Loss: 91489.3438 | Validation Accuracy: 0.4342
# Epoch 17, CIFAR-10 Batch 1:  Loss: 64142.3594 | Validation Accuracy: 0.4470
# Epoch 17, CIFAR-10 Batch 2:  Loss: 70044.9531 | Validation Accuracy: 0.4386
# Epoch 17, CIFAR-10 Batch 3:  Loss:  5161.0439 | Validation Accuracy: 0.4542
# Epoch 17, CIFAR-10 Batch 4:  Loss: 50209.1562 | Validation Accuracy: 0.4560
# Epoch 17, CIFAR-10 Batch 5:  Loss: 69711.3125 | Validation Accuracy: 0.4374
# Epoch 18, CIFAR-10 Batch 1:  Loss: 60886.8555 | Validation Accuracy: 0.4522
# Epoch 18, CIFAR-10 Batch 2:  Loss: 55540.5938 | Validation Accuracy: 0.4412
# Epoch 18, CIFAR-10 Batch 3:  Loss:  7442.6626 | Validation Accuracy: 0.4458
# Epoch 18, CIFAR-10 Batch 4:  Loss: 31524.7227 | Validation Accuracy: 0.4580
# Epoch 18, CIFAR-10 Batch 5:  Loss: 40278.8789 | Validation Accuracy: 0.4350
# Epoch 19, CIFAR-10 Batch 1:  Loss: 52288.8906 | Validation Accuracy: 0.4634
# Epoch 19, CIFAR-10 Batch 2:  Loss: 54566.3750 | Validation Accuracy: 0.4478
# Epoch 19, CIFAR-10 Batch 3:  Loss:  3572.4595 | Validation Accuracy: 0.4572
# Epoch 19, CIFAR-10 Batch 4:  Loss: 15339.0312 | Validation Accuracy: 0.4562
# Epoch 19, CIFAR-10 Batch 5:  Loss: 43666.6602 | Validation Accuracy: 0.4396
# Epoch 20, CIFAR-10 Batch 1:  Loss: 42405.0391 | Validation Accuracy: 0.4624
# Epoch 20, CIFAR-10 Batch 2:  Loss: 46308.5938 | Validation Accuracy: 0.4520
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4616
# Epoch 20, CIFAR-10 Batch 4:  Loss: 24161.0098 | Validation Accuracy: 0.4618
# Epoch 20, CIFAR-10 Batch 5:  Loss: 21734.8379 | Validation Accuracy: 0.4588
# Epoch 21, CIFAR-10 Batch 1:  Loss: 30997.5566 | Validation Accuracy: 0.4714
# Epoch 21, CIFAR-10 Batch 2:  Loss: 37596.0273 | Validation Accuracy: 0.4588
# Epoch 21, CIFAR-10 Batch 3:  Loss:  2559.9375 | Validation Accuracy: 0.4640
# Epoch 21, CIFAR-10 Batch 4:  Loss: 25394.7852 | Validation Accuracy: 0.4562
# Epoch 21, CIFAR-10 Batch 5:  Loss: 26475.1152 | Validation Accuracy: 0.4592
# Epoch 22, CIFAR-10 Batch 1:  Loss: 20850.7070 | Validation Accuracy: 0.4678
# Epoch 22, CIFAR-10 Batch 2:  Loss: 27969.1230 | Validation Accuracy: 0.4576
# Epoch 22, CIFAR-10 Batch 3:  Loss:   974.8250 | Validation Accuracy: 0.4606
# Epoch 22, CIFAR-10 Batch 4:  Loss: 18055.0273 | Validation Accuracy: 0.4540
# Epoch 22, CIFAR-10 Batch 5:  Loss: 14940.7598 | Validation Accuracy: 0.4720
# Epoch 23, CIFAR-10 Batch 1:  Loss: 19133.8066 | Validation Accuracy: 0.4716
# Epoch 23, CIFAR-10 Batch 2:  Loss: 21196.7910 | Validation Accuracy: 0.4686
# Epoch 23, CIFAR-10 Batch 3:  Loss:  3701.7468 | Validation Accuracy: 0.4584
# Epoch 23, CIFAR-10 Batch 4:  Loss: 23403.2891 | Validation Accuracy: 0.4674
# Epoch 23, CIFAR-10 Batch 5:  Loss:  8595.9160 | Validation Accuracy: 0.4660
# Epoch 24, CIFAR-10 Batch 1:  Loss: 20709.0781 | Validation Accuracy: 0.4742
# Epoch 24, CIFAR-10 Batch 2:  Loss: 16387.3027 | Validation Accuracy: 0.4584
# Epoch 24, CIFAR-10 Batch 3:  Loss:  1658.2125 | Validation Accuracy: 0.4580
# Epoch 24, CIFAR-10 Batch 4:  Loss: 12999.5908 | Validation Accuracy: 0.4628
# Epoch 24, CIFAR-10 Batch 5:  Loss: 10291.0039 | Validation Accuracy: 0.4688
# Epoch 25, CIFAR-10 Batch 1:  Loss: 10463.9209 | Validation Accuracy: 0.4756
# Epoch 25, CIFAR-10 Batch 2:  Loss:  7809.0347 | Validation Accuracy: 0.4624
# Epoch 25, CIFAR-10 Batch 3:  Loss:  3916.6001 | Validation Accuracy: 0.4590
# Epoch 25, CIFAR-10 Batch 4:  Loss: 14642.5312 | Validation Accuracy: 0.4608
# Epoch 25, CIFAR-10 Batch 5:  Loss:  5405.2388 | Validation Accuracy: 0.4746
# Epoch 26, CIFAR-10 Batch 1:  Loss: 19092.4941 | Validation Accuracy: 0.4792
# Epoch 26, CIFAR-10 Batch 2:  Loss:  5348.9253 | Validation Accuracy: 0.4676
# Epoch 26, CIFAR-10 Batch 3:  Loss:  3558.7002 | Validation Accuracy: 0.4532
# Epoch 26, CIFAR-10 Batch 4:  Loss: 16219.5566 | Validation Accuracy: 0.4648
# Epoch 26, CIFAR-10 Batch 5:  Loss:  3801.0596 | Validation Accuracy: 0.4732
# Epoch 27, CIFAR-10 Batch 1:  Loss: 12881.7852 | Validation Accuracy: 0.4732
# Epoch 27, CIFAR-10 Batch 2:  Loss:   639.8375 | Validation Accuracy: 0.4682
# Epoch 27, CIFAR-10 Batch 3:  Loss:  3206.9937 | Validation Accuracy: 0.4542
# Epoch 27, CIFAR-10 Batch 4:  Loss: 22055.0195 | Validation Accuracy: 0.4574
# Epoch 27, CIFAR-10 Batch 5:  Loss: 19182.4355 | Validation Accuracy: 0.4688
# Epoch 28, CIFAR-10 Batch 1:  Loss:  4997.7158 | Validation Accuracy: 0.4676
# Epoch 28, CIFAR-10 Batch 2:  Loss:  5837.3779 | Validation Accuracy: 0.4778
# Epoch 28, CIFAR-10 Batch 3:  Loss: 10363.3438 | Validation Accuracy: 0.4550
# Epoch 28, CIFAR-10 Batch 4:  Loss:  9925.2402 | Validation Accuracy: 0.4646
# Epoch 28, CIFAR-10 Batch 5:  Loss:  8093.9956 | Validation Accuracy: 0.4750
# Epoch 29, CIFAR-10 Batch 1:  Loss:  5547.1016 | Validation Accuracy: 0.4774
# Epoch 29, CIFAR-10 Batch 2:  Loss:  8617.6943 | Validation Accuracy: 0.4700
# Epoch 35, CIFAR-10 Batch 4:  Loss:  5585.8579 | Validation Accuracy: 0.4540
# Epoch 35, CIFAR-10 Batch 5:  Loss:  1205.8438 | Validation Accuracy: 0.4728
# Epoch 36, CIFAR-10 Batch 1:  Loss:  2274.0781 | Validation Accuracy: 0.4822
# Epoch 36, CIFAR-10 Batch 2:  Loss:  1314.7281 | Validation Accuracy: 0.4870
# Epoch 36, CIFAR-10 Batch 3:  Loss:  1161.1047 | Validation Accuracy: 0.4686
# Epoch 36, CIFAR-10 Batch 4:  Loss:  5082.7173 | Validation Accuracy: 0.4474
# Epoch 36, CIFAR-10 Batch 5:  Loss:  5578.7876 | Validation Accuracy: 0.4804
# Epoch 37, CIFAR-10 Batch 1:  Loss:   829.9875 | Validation Accuracy: 0.4746
# Epoch 37, CIFAR-10 Batch 2:  Loss:  2563.0000 | Validation Accuracy: 0.4824
# Epoch 37, CIFAR-10 Batch 3:  Loss:  2475.4548 | Validation Accuracy: 0.4772
# Epoch 37, CIFAR-10 Batch 4:  Loss:  5072.7969 | Validation Accuracy: 0.4650
# Epoch 37, CIFAR-10 Batch 5:  Loss:    83.8906 | Validation Accuracy: 0.4802
# Epoch 38, CIFAR-10 Batch 1:  Loss:  5280.9893 | Validation Accuracy: 0.4768
# Epoch 38, CIFAR-10 Batch 2:  Loss:  2218.8125 | Validation Accuracy: 0.4834
# Epoch 38, CIFAR-10 Batch 3:  Loss:   862.4047 | Validation Accuracy: 0.4648
# Epoch 38, CIFAR-10 Batch 4:  Loss:  5501.7705 | Validation Accuracy: 0.4678
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4804
# Epoch 39, CIFAR-10 Batch 1:  Loss:  1943.6797 | Validation Accuracy: 0.4910
# Epoch 39, CIFAR-10 Batch 2:  Loss:  2090.2109 | Validation Accuracy: 0.4730
# Epoch 39, CIFAR-10 Batch 3:  Loss:  1924.1453 | Validation Accuracy: 0.4584
# Epoch 39, CIFAR-10 Batch 4:  Loss:  2315.9187 | Validation Accuracy: 0.4740
# Epoch 39, CIFAR-10 Batch 5:  Loss:  1370.0673 | Validation Accuracy: 0.4804
# Epoch 40, CIFAR-10 Batch 1:  Loss:  2163.9485 | Validation Accuracy: 0.4816
# Epoch 40, CIFAR-10 Batch 2:  Loss:  1426.6062 | Validation Accuracy: 0.4634
# Epoch 40, CIFAR-10 Batch 3:  Loss:  4012.1860 | Validation Accuracy: 0.4606
# Epoch 40, CIFAR-10 Batch 4:  Loss:   944.3563 | Validation Accuracy: 0.4800
# Epoch 40, CIFAR-10 Batch 5:  Loss:  3677.4658 | Validation Accuracy: 0.4838
# Epoch 41, CIFAR-10 Batch 1:  Loss:   258.0000 | Validation Accuracy: 0.4808
# Epoch 41, CIFAR-10 Batch 2:  Loss:  7177.5347 | Validation Accuracy: 0.4600
# Epoch 41, CIFAR-10 Batch 3:  Loss:  2091.7627 | Validation Accuracy: 0.4728
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4810
# Epoch 41, CIFAR-10 Batch 5:  Loss:  3549.4065 | Validation Accuracy: 0.4736
# Epoch 42, CIFAR-10 Batch 1:  Loss:  9666.6738 | Validation Accuracy: 0.4752
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4966
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4842
# Epoch 42, CIFAR-10 Batch 4:  Loss:   778.8156 | Validation Accuracy: 0.4820
# Epoch 42, CIFAR-10 Batch 5:  Loss:  1727.8344 | Validation Accuracy: 0.4758
# Epoch 43, CIFAR-10 Batch 1:  Loss:  3720.6123 | Validation Accuracy: 0.4654
# Epoch 43, CIFAR-10 Batch 2:  Loss:  4348.5830 | Validation Accuracy: 0.4730
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4862
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4748
# Epoch 43, CIFAR-10 Batch 5:  Loss:    63.3937 | Validation Accuracy: 0.4720
# Epoch 44, CIFAR-10 Batch 1:  Loss:  2756.7297 | Validation Accuracy: 0.4892
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4894
# Epoch 44, CIFAR-10 Batch 3:  Loss:  1875.8032 | Validation Accuracy: 0.4826
# Epoch 44, CIFAR-10 Batch 4:  Loss:   657.6391 | Validation Accuracy: 0.4692
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4992
# Epoch 45, CIFAR-10 Batch 1:  Loss:  2441.6814 | Validation Accuracy: 0.4928
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4860
# Epoch 45, CIFAR-10 Batch 3:  Loss:  2213.6641 | Validation Accuracy: 0.4824
# Epoch 45, CIFAR-10 Batch 4:  Loss:   510.7781 | Validation Accuracy: 0.4816
# Epoch 45, CIFAR-10 Batch 5:  Loss:   118.6813 | Validation Accuracy: 0.5018
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4936
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4902
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5002
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4834
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4920
# Epoch 47, CIFAR-10 Batch 1:  Loss:   370.5031 | Validation Accuracy: 0.4910
# Epoch 47, CIFAR-10 Batch 2:  Loss:   849.7609 | Validation Accuracy: 0.4850
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5006
# Epoch 47, CIFAR-10 Batch 4:  Loss:  2900.3672 | Validation Accuracy: 0.4804
# Epoch 47, CIFAR-10 Batch 5:  Loss:   408.4312 | Validation Accuracy: 0.4944
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4946
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4864
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5046
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4884
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.4878
# Epoch 49, CIFAR-10 Batch 1:  Loss:   322.8563 | Validation Accuracy: 0.5010
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4914
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.4996
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4950
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5116
# Epoch 50, CIFAR-10 Batch 1:  Loss:  2131.0234 | Validation Accuracy: 0.4994
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4942
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5078
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4924
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5096
# Epoch 51, CIFAR-10 Batch 1:  Loss:   676.2906 | Validation Accuracy: 0.4992
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4952
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5174
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5062
# Epoch 51, CIFAR-10 Batch 5:  Loss:    18.8422 | Validation Accuracy: 0.5128
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4934
# Epoch 52, CIFAR-10 Batch 2:  Loss:   889.2781 | Validation Accuracy: 0.4994
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5004
# Epoch 52, CIFAR-10 Batch 4:  Loss:   185.6844 | Validation Accuracy: 0.5004
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5104
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4814
# Epoch 53, CIFAR-10 Batch 2:  Loss:   130.3063 | Validation Accuracy: 0.4884
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5012
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5038
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5102
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4900
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4910
# Epoch 54, CIFAR-10 Batch 3:  Loss:   104.0406 | Validation Accuracy: 0.4962
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4754
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5140
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4942
# Epoch 55, CIFAR-10 Batch 2:  Loss:  1236.2891 | Validation Accuracy: 0.4928
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5042
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4880
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5084
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5014
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4988
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5026
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4920
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5062
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5022
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5004
# Epoch 57, CIFAR-10 Batch 3:  Loss:    12.6531 | Validation Accuracy: 0.5154
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4958
# Epoch 57, CIFAR-10 Batch 5:  Loss:  3036.1235 | Validation Accuracy: 0.5130
# Epoch 58, CIFAR-10 Batch 1:  Loss:    25.1625 | Validation Accuracy: 0.5026
# Epoch 58, CIFAR-10 Batch 2:  Loss:   886.4125 | Validation Accuracy: 0.4982
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5012
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5102
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5140
# Epoch 59, CIFAR-10 Batch 1:  Loss:  1046.2484 | Validation Accuracy: 0.5114
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4980
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5156
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5096
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5216
# Epoch 60, CIFAR-10 Batch 1:  Loss:  1478.9657 | Validation Accuracy: 0.4908
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4914
# Epoch 60, CIFAR-10 Batch 3:  Loss:  1450.8219 | Validation Accuracy: 0.5104
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5078
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5168
# Epoch 61, CIFAR-10 Batch 1:  Loss:   324.8906 | Validation Accuracy: 0.4976
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4872
# Epoch 61, CIFAR-10 Batch 3:  Loss:    22.2703 | Validation Accuracy: 0.5114
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5170
# Epoch 61, CIFAR-10 Batch 5:  Loss:   122.0625 | Validation Accuracy: 0.5146
# Epoch 62, CIFAR-10 Batch 1:  Loss:  4585.7471 | Validation Accuracy: 0.4882
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4836
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5206
# Epoch 62, CIFAR-10 Batch 4:  Loss:   276.6836 | Validation Accuracy: 0.4982
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5250
# Epoch 63, CIFAR-10 Batch 1:  Loss:    62.1641 | Validation Accuracy: 0.5014
# Epoch 63, CIFAR-10 Batch 2:  Loss:   545.1125 | Validation Accuracy: 0.4830
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5098
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5146
# Epoch 63, CIFAR-10 Batch 5:  Loss:  1239.9437 | Validation Accuracy: 0.5106
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.4904
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4948
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5054
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5078
# Epoch 64, CIFAR-10 Batch 5:  Loss:   855.4453 | Validation Accuracy: 0.5102
# Epoch 65, CIFAR-10 Batch 1:  Loss:    78.9711 | Validation Accuracy: 0.4972
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4982
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5126
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5102
# Epoch 65, CIFAR-10 Batch 5:  Loss:   151.6891 | Validation Accuracy: 0.5194
# Epoch 66, CIFAR-10 Batch 1:  Loss:   469.4719 | Validation Accuracy: 0.4996
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.4954
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5216
# Epoch 66, CIFAR-10 Batch 4:  Loss:   450.2266 | Validation Accuracy: 0.5046
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5142
# Epoch 67, CIFAR-10 Batch 1:  Loss:   247.5273 | Validation Accuracy: 0.5076
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5118
# Epoch 67, CIFAR-10 Batch 3:  Loss:  1303.2500 | Validation Accuracy: 0.5110
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5102
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5268
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5180
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5002
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5164
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5174
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5224
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5048
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5042
# Epoch 69, CIFAR-10 Batch 3:  Loss:   417.7766 | Validation Accuracy: 0.5146
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5034
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5246
# Epoch 70, CIFAR-10 Batch 1:  Loss:   183.9195 | Validation Accuracy: 0.5214
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5034
# Epoch 70, CIFAR-10 Batch 3:  Loss:   324.9563 | Validation Accuracy: 0.5202
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5032
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5308
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5252
# Epoch 71, CIFAR-10 Batch 2:  Loss:   978.2469 | Validation Accuracy: 0.4994
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5194
# Epoch 71, CIFAR-10 Batch 4:  Loss:   259.9406 | Validation Accuracy: 0.4954
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5204
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5154
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5034
# Epoch 72, CIFAR-10 Batch 3:  Loss:   405.4062 | Validation Accuracy: 0.5202
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5136
# Epoch 72, CIFAR-10 Batch 5:  Loss:   163.8672 | Validation Accuracy: 0.5338
# Epoch 73, CIFAR-10 Batch 1:  Loss:    24.0406 | Validation Accuracy: 0.5276
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5184
# Epoch 73, CIFAR-10 Batch 3:  Loss:   469.0531 | Validation Accuracy: 0.5094
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5072
# Epoch 73, CIFAR-10 Batch 5:  Loss:   521.2875 | Validation Accuracy: 0.5324
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5304
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5070
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5188
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5152
# Epoch 74, CIFAR-10 Batch 5:  Loss:   359.8930 | Validation Accuracy: 0.5258
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5158
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5152
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5084
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5150
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5298
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5336
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5100
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5264
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.4986
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5278
# Epoch 77, CIFAR-10 Batch 1:  Loss:   314.5656 | Validation Accuracy: 0.5258
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5148
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5010
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5168
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5290
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5342
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5216
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5240
# Epoch 78, CIFAR-10 Batch 4:  Loss:    22.2563 | Validation Accuracy: 0.5196
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5348
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5298
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5314
# Epoch 79, CIFAR-10 Batch 3:  Loss:   350.1781 | Validation Accuracy: 0.5354
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5106
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5296
# Epoch 80, CIFAR-10 Batch 1:  Loss:  1323.1781 | Validation Accuracy: 0.5276
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5092
# Epoch 80, CIFAR-10 Batch 3:  Loss:   283.0078 | Validation Accuracy: 0.5228
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5118
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5316
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5306
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5158
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5372
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5124
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5296
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5326
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5182
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5310
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5252
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5434
# Epoch 83, CIFAR-10 Batch 1:  Loss:   388.3773 | Validation Accuracy: 0.5376
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5528
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5386
# Epoch 83, CIFAR-10 Batch 4:  Loss:   357.6695 | Validation Accuracy: 0.5382
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5344
# Epoch 84, CIFAR-10 Batch 1:  Loss:   602.8063 | Validation Accuracy: 0.5248
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5360
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5278
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5356
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5350
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5252
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5366
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5346
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5328
# Epoch 85, CIFAR-10 Batch 5:  Loss:   174.4781 | Validation Accuracy: 0.5318
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5358
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5384
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5344
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5266
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5332
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5274
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5452
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5320
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5360
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5282
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5380
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5336
# Epoch 88, CIFAR-10 Batch 4:  Loss:   244.0563 | Validation Accuracy: 0.5318
# Epoch 88, CIFAR-10 Batch 5:  Loss:   231.3539 | Validation Accuracy: 0.5338
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5330
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5444
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5288
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5352
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5374
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5326
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5340
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5334
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5276
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5294
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5170
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5410
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5352
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5380
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5428
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5356
# Epoch 92, CIFAR-10 Batch 2:  Loss:   525.6578 | Validation Accuracy: 0.5404
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5324
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5322
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5442
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5184
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5380
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5258
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5264
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5392
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5304
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5348
# Epoch 94, CIFAR-10 Batch 3:  Loss:    89.9125 | Validation Accuracy: 0.5310
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5338
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5418
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5460
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5464
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5278
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5330
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5416
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5408
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5464
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5390
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5288
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5316
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5298
# Epoch 97, CIFAR-10 Batch 2:  Loss:   188.1281 | Validation Accuracy: 0.5460
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5374
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5278
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5424
# Epoch 98, CIFAR-10 Batch 1:  Loss:   246.6188 | Validation Accuracy: 0.5426
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5486
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5384
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5384
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5482
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5398
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5512
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5410
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5280
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5326
# Epoch 100, CIFAR-10 Batch 1:  Loss:   468.5031 | Validation Accuracy: 0.5266
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5436
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5462
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5296
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5416
# Epoch 101, CIFAR-10 Batch 1:  Loss:    62.1164 | Validation Accuracy: 0.5464
# Epoch 101, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5490
# Epoch 101, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5524
# Epoch 101, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5278
# Epoch 101, CIFAR-10 Batch 5:  Loss:     1.4477 | Validation Accuracy: 0.5488
# Epoch 102, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5324
# Epoch 102, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5412
# Epoch 102, CIFAR-10 Batch 3:  Loss:    40.4906 | Validation Accuracy: 0.5536
# Epoch 102, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5406
# Epoch 102, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5504
# Epoch 103, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5410
# Epoch 103, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5468
# Epoch 103, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5198
# Epoch 103, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5468
# Epoch 103, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5382
# Epoch 104, CIFAR-10 Batch 1:  Loss:   724.5344 | Validation Accuracy: 0.5340
# Epoch 104, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5532
# Epoch 104, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5476
# Epoch 104, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5334
# Epoch 104, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5424
# Epoch 105, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5264
# Epoch 105, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5502
# Epoch 105, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5502
# Epoch 105, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5418
# Epoch 105, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5464
# Epoch 106, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5392
# Epoch 106, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5442
# Epoch 106, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5506
# Epoch 106, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5394
# Epoch 106, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5236
# Epoch 107, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5368
# Epoch 107, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5566
# Epoch 107, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5532
# Epoch 107, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5400
# Epoch 107, CIFAR-10 Batch 5:  Loss:   117.4305 | Validation Accuracy: 0.5392
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5394
# Epoch 108, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5500
# Epoch 108, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5504
# Epoch 108, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5326
# Epoch 108, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5404
# Epoch 109, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5346
# Epoch 109, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5442
# Epoch 109, CIFAR-10 Batch 3:  Loss:   268.0922 | Validation Accuracy: 0.5488
# Epoch 109, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5368
# Epoch 109, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5480
# Epoch 110, CIFAR-10 Batch 1:  Loss:   120.0328 | Validation Accuracy: 0.5364
# Epoch 110, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5316
# Epoch 110, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5506
# Epoch 110, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5454
# Epoch 110, CIFAR-10 Batch 5:  Loss:   146.5734 | Validation Accuracy: 0.5434
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5476
# Epoch 111, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5388
# Epoch 111, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5434
# Epoch 111, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5502
# Epoch 111, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5390
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5452
# Epoch 112, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5508
# Epoch 112, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5372
# Epoch 112, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5340
# Epoch 112, CIFAR-10 Batch 5:  Loss:    33.2914 | Validation Accuracy: 0.5380
# Epoch 113, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5376
# Epoch 113, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5504
# Epoch 113, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5494
# Epoch 113, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5498
# Epoch 113, CIFAR-10 Batch 5:  Loss:   289.8188 | Validation Accuracy: 0.5492
# Epoch 114, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5454
# Epoch 114, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5536
# Epoch 114, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5532
# Epoch 114, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5500
# Epoch 114, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5442
# Epoch 115, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5394
# Epoch 115, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5528
# Epoch 115, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5424
# Epoch 115, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5446
# Epoch 116, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5408
# Epoch 116, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5466
# Epoch 116, CIFAR-10 Batch 3:  Loss:    25.6375 | Validation Accuracy: 0.5492
# Epoch 116, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5420
# Epoch 116, CIFAR-10 Batch 5:  Loss:    39.2031 | Validation Accuracy: 0.5508
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5474
# Epoch 117, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5496
# Epoch 117, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5500
# Epoch 117, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5334
# Epoch 117, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.
CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5908
# Epoch 473, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5812
# Epoch 473, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5746
# Epoch 474, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5856
# Epoch 474, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5860
# Epoch 474, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5902
# Epoch 474, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5982
# Epoch 474, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5814
# Epoch 475, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5954
# Epoch 475, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5896
# Epoch 475, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5862
# Epoch 475, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5874
# Epoch 475, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5774
# Epoch 476, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5856
# Epoch 476, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5958
# Epoch 476, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5972
# Epoch 476, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5916
# Epoch 476, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5992
# Epoch 477, CIFAR-10 Batch 1:  Loss:   148.1750 | Validation Accuracy: 0.5928
# Epoch 477, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5974
# Epoch 477, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5886
# Epoch 477, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5946
# Epoch 477, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5898
# Epoch 478, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6028
# Epoch 478, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5928
# Epoch 478, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5996
# Epoch 478, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5880
# Epoch 478, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5974
# Epoch 479, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6018
# Epoch 479, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6002
# Epoch 479, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6064
# Epoch 479, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5916
# Epoch 479, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5974
# Epoch 480, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5936
# Epoch 480, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6018
# Epoch 480, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5970
# Epoch 480, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5840
# Epoch 480, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5982
# Epoch 481, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6020
# Epoch 481, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5922
# Epoch 481, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6000
# Epoch 481, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5984
# Epoch 481, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5996
# Epoch 482, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5950
# Epoch 482, CIFAR-10 Batch 2:  Loss:   655.3156 | Validation Accuracy: 0.6088
# Epoch 482, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5934
# Epoch 482, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5966
# Epoch 482, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5966
# Epoch 483, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5906
# Epoch 483, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6076
# Epoch 483, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6024
# Epoch 483, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5942
# Epoch 483, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5908
# Epoch 484, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6042
# Epoch 484, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5950
# Epoch 484, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6012
# Epoch 484, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5972
# Epoch 484, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5974
# Epoch 485, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5984
# Epoch 485, CIFAR-10 Batch 2:  Loss:   113.5734 | Validation Accuracy: 0.5838
# Epoch 485, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6014
# Epoch 485, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5898
# Epoch 485, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5968
# Epoch 486, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5896
# Epoch 486, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5944
# Epoch 486, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6026
# Epoch 486, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5884
# Epoch 486, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5886
# Epoch 487, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5938
# Epoch 487, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5952
# Epoch 487, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5970
# Epoch 487, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5892
# Epoch 487, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5972
# Epoch 488, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5970
# Epoch 488, CIFAR-10 Batch 2:  Loss:   113.6922 | Validation Accuracy: 0.6004
# Epoch 488, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6106
# Epoch 488, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.6074
# Epoch 488, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6012
# Epoch 489, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5950
# Epoch 489, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5984
# Epoch 489, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5952
# Epoch 489, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5964
# Epoch 489, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6002
# Epoch 490, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5996
# Epoch 490, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5992
# Epoch 490, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5874
# Epoch 490, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5940
# Epoch 490, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5962
# Epoch 491, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5930
# Epoch 491, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6020
# Epoch 491, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5984
# Epoch 491, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5890
# Epoch 491, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6024
# Epoch 492, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5900
# Epoch 492, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6018
# Epoch 492, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5942
# Epoch 492, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5800
# Epoch 492, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5976
# Epoch 493, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5912
# Epoch 493, CIFAR-10 Batch 2:  Loss:   144.9688 | Validation Accuracy: 0.5880
# Epoch 493, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6012
# Epoch 493, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5926
# Epoch 493, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5948
# Epoch 494, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5944
# Epoch 494, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6002
# Epoch 494, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5998
# Epoch 494, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5944
# Epoch 494, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6022
# Epoch 495, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6014
# Epoch 495, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6026
# Epoch 495, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6036
# Epoch 495, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5968
# Epoch 495, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5948
# Epoch 496, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6000
# Epoch 496, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6008
# Epoch 496, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6022
# Epoch 496, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5890
# Epoch 496, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5904
# Epoch 497, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5990
# Epoch 497, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5948
# Epoch 497, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6024
# Epoch 497, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5970
# Epoch 497, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5976
# Epoch 498, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5962
# Epoch 498, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5968
# Epoch 498, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5864
# Epoch 498, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5914
# Epoch 498, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5954
# Epoch 499, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.6064
# Epoch 499, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.6024
# Epoch 499, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.5992
# Epoch 499, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5882
# Epoch 499, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.5926
# Epoch 500, CIFAR-10 Batch 1:  Loss:     0.0000 | Validation Accuracy: 0.5890
# Epoch 500, CIFAR-10 Batch 2:  Loss:     0.0000 | Validation Accuracy: 0.5862
# Epoch 500, CIFAR-10 Batch 3:  Loss:     0.0000 | Validation Accuracy: 0.6050
# Epoch 500, CIFAR-10 Batch 4:  Loss:     0.0000 | Validation Accuracy: 0.5792
# Epoch 500, CIFAR-10 Batch 5:  Loss:     0.0000 | Validation Accuracy: 0.6072

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6048259493670886

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
